# %%
from IPython.display import Image

# %% [markdown]
# # FocusedFashion
#
# ### Mary Gibbs and Jessica Fogerty
# ##### Final Project
# ##### Machine Learning II
# ##### The George Washington University

# %% [markdown]
# # Overview

# %% [markdown]
# # Related Work

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Labels

# %% [markdown]
# ![Histogram](Histogram_labels.png)

# %% [markdown]
# ![word cloud](word_cloud.png)

# %% [markdown]
# # Models

# %% [markdown]
# ## Simple CNN

# %%
Image(filename='loss_plot_model_6.png')

# %% [markdown]
# ## MobileNet

# %%
Image(filename='loss_plot_mobile_net.png')

# %%
Image(filename='box_plot_f1.png')

# %% [markdown]
# ## ResNet

# %% [markdown]
# # Model Summary

# %% [markdown]
# ## Recommendation System

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Project Limitations & Future Work

# %% [markdown]
# # References
